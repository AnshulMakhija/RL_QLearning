# %%
import numpy as np
import random

# %%
class Grid():
    def __init__(self,size=5):
        self.size = size
        self.start = (0,0)
        self.goal = (4,4)
        self.reset()
        
    def reset(self):
        self.agent_pos = self.start
        return self.agent_pos
    
    def state(self):
        return self.agent_pos
    
    def goal_state(self):
        return self.goal
    
    def step(self, action):
        x,y = self.agent_pos
        
        if action == 'up':
            x = max(0, x-1)
            
        elif action == 'down':
            x = min(self.size-1, x+1)
            
        elif action == 'left':
            y = max(0, y-1)
            
        elif action == 'right':
            y = min(self.size-1, y+1)
            
        self.agent_pos = (x,y)
        
        reward = 10 if self.agent_pos == self.goal else -1
        done = self.agent_pos == self.goal
        return self.agent_pos, reward, done

# %% [markdown]
# # Moves

# %%
environment = Grid()
actions = [0,1,2,3] # up, down, left, right
action_names = ['up', 'down', 'left', 'right']

# %% [markdown]
# # Q-Table
#     Table format: [x y action] example: [x,y,3] # last one is action

# %%
Q = np.zeros((environment.size, environment.size, len(actions)))

# %% [markdown]
# # Parameters

# %%
alpha = 0.1 # learning rate
gamma = 0.9 # discount factor
epsilon = 0.2  # exploration rate
episodes = 100

# %%
for episode in range(episodes):
    state = environment.reset()
    done = False
    total_reward = 0
    steps = 0
    
    while not done:
        x, y = state
        
        # ε-greedy action: explore vs exploit
        if random.random() < epsilon:
            action = random.choice(actions) # explore
        else:
            action = np.argmax(Q[x,y]) # exploit already learned values
            
        next_state, reward, done = environment.step(action_names[action])
        next_x, next_y = next_state
        
        # Q-learning update
        # current reward + future best reward from new state.
        # Q(s, a) = Q(s, a) + α * [R + γ * max_a' Q(s', a') - Q(s, a)]
        best_next_q = np.max(Q[next_x, next_y])
        Q[x, y, action] = Q[x, y, action] + alpha * (reward + gamma * best_next_q - Q[x, y, action])

        state = next_state
        total_reward += reward
        steps += 1
        
    print(f"Episode {episode+1}: Total Reward: {total_reward}, Steps: {steps}")
# Out:
# Episode 1: Total Reward: -127, Steps: 138
# Episode 2: Total Reward: -44, Steps: 55
# Episode 3: Total Reward: -41, Steps: 52
# Episode 4: Total Reward: -5, Steps: 16
# Episode 5: Total Reward: -14, Steps: 25
# Episode 6: Total Reward: -18, Steps: 29
# Episode 7: Total Reward: -20, Steps: 31
# Episode 8: Total Reward: -40, Steps: 51
# Episode 9: Total Reward: -1, Steps: 12
# Episode 10: Total Reward: -57, Steps: 68
# Episode 11: Total Reward: -24, Steps: 35
# Episode 12: Total Reward: -40, Steps: 51
# Episode 13: Total Reward: -7, Steps: 18
# Episode 14: Total Reward: -12, Steps: 23
# Episode 15: Total Reward: -4, Steps: 15
# Episode 16: Total Reward: -14, Steps: 25
# Episode 17: Total Reward: -17, Steps: 28
# Episode 18: Total Reward: -8, Steps: 19
# Episode 19: Total Reward: -16, Steps: 27
# Episode 20: Total Reward: -9, Steps: 20
# Episode 21: Total Reward: 1, Steps: 10
# Episode 22: Total Reward: -11, Steps: 22
# Episode 23: Total Reward: 0, Steps: 11
# Episode 24: Total Reward: 0, Steps: 11
# Episode 25: Total Reward: -10, Steps: 21
# Episode 26: Total Reward: -4, Steps: 15
# Episode 27: Total Reward: -16, Steps: 27
# Episode 28: Total Reward: -6, Steps: 17
# Episode 29: Total Reward: -26, Steps: 37
# Episode 30: Total Reward: 1, Steps: 10
# Episode 31: Total Reward: 3, Steps: 8
# Episode 32: Total Reward: -11, Steps: 22
# Episode 33: Total Reward: 2, Steps: 9
# Episode 34: Total Reward: -3, Steps: 14
# Episode 35: Total Reward: 2, Steps: 9
# Episode 36: Total Reward: -2, Steps: 13
# Episode 37: Total Reward: 1, Steps: 10
# Episode 38: Total Reward: -4, Steps: 15
# Episode 39: Total Reward: -14, Steps: 25
# Episode 40: Total Reward: -1, Steps: 12
# Episode 41: Total Reward: -4, Steps: 15
# Episode 42: Total Reward: 3, Steps: 8
# Episode 43: Total Reward: -7, Steps: 18
# Episode 44: Total Reward: 2, Steps: 9
# Episode 45: Total Reward: -6, Steps: 17
# Episode 46: Total Reward: 1, Steps: 10
# Episode 47: Total Reward: 0, Steps: 11
# Episode 48: Total Reward: 3, Steps: 8
# Episode 49: Total Reward: -1, Steps: 12
# Episode 50: Total Reward: -9, Steps: 20
# Episode 51: Total Reward: 1, Steps: 10
# Episode 52: Total Reward: -4, Steps: 15
# Episode 53: Total Reward: 2, Steps: 9
# Episode 54: Total Reward: 0, Steps: 11
# Episode 55: Total Reward: -1, Steps: 12
# Episode 56: Total Reward: 2, Steps: 9
# Episode 57: Total Reward: 1, Steps: 10
# Episode 58: Total Reward: -1, Steps: 12
# Episode 59: Total Reward: 0, Steps: 11
# Episode 60: Total Reward: -5, Steps: 16
# Episode 61: Total Reward: -3, Steps: 14
# Episode 62: Total Reward: 3, Steps: 8
# Episode 63: Total Reward: -4, Steps: 15
# Episode 64: Total Reward: -1, Steps: 12
# Episode 65: Total Reward: 2, Steps: 9
# Episode 66: Total Reward: -4, Steps: 15
# Episode 67: Total Reward: 0, Steps: 11
# Episode 68: Total Reward: 1, Steps: 10
# Episode 69: Total Reward: 1, Steps: 10
# Episode 70: Total Reward: 3, Steps: 8
# Episode 71: Total Reward: 0, Steps: 11
# Episode 72: Total Reward: -2, Steps: 13
# Episode 73: Total Reward: 3, Steps: 8
# Episode 74: Total Reward: 1, Steps: 10
# Episode 75: Total Reward: -1, Steps: 12
# Episode 76: Total Reward: 1, Steps: 10
# Episode 77: Total Reward: -1, Steps: 12
# Episode 78: Total Reward: 3, Steps: 8
# Episode 79: Total Reward: 3, Steps: 8
# Episode 80: Total Reward: 0, Steps: 11
# Episode 81: Total Reward: 3, Steps: 8
# Episode 82: Total Reward: 3, Steps: 8
# Episode 83: Total Reward: 3, Steps: 8
# Episode 84: Total Reward: 3, Steps: 8
# Episode 85: Total Reward: 3, Steps: 8
# Episode 86: Total Reward: 3, Steps: 8
# Episode 87: Total Reward: 0, Steps: 11
# Episode 88: Total Reward: 3, Steps: 8
# Episode 89: Total Reward: 3, Steps: 8
# Episode 90: Total Reward: 2, Steps: 9
# Episode 91: Total Reward: 3, Steps: 8
# Episode 92: Total Reward: -4, Steps: 15
# Episode 93: Total Reward: 1, Steps: 10
# Episode 94: Total Reward: -3, Steps: 14
# Episode 95: Total Reward: 1, Steps: 10
# Episode 96: Total Reward: 1, Steps: 10
# Episode 97: Total Reward: 3, Steps: 8
# Episode 98: Total Reward: 3, Steps: 8
# Episode 99: Total Reward: 3, Steps: 8
# Episode 100: Total Reward: 3, Steps: 8

# %%
def print_q_table(Q):
    action_names = ['up', 'down', 'left', 'right']
    for i in range(environment.size):
        for j in range(environment.size):
            print(f"State ({i},{j}):")
            for a in range(4):
                print(f"  Action {action_names[a]}: {Q[i,j,a]:.2f}")
            print("-" * 30)

print("Q-Table (State, Action Values):")
print_q_table(Q)
# Out:
# Q-Table (State, Action Values):
# State (0,0):
#   Action up: -2.97
#   Action down: -2.52
#   Action left: -2.93
#   Action right: -2.83
# ------------------------------
# State (0,1):
#   Action up: -2.27
#   Action down: -2.17
#   Action left: -2.20
#   Action right: -1.96
# ------------------------------
# State (0,2):
#   Action up: -1.55
#   Action down: -0.41
#   Action left: -1.68
#   Action right: -1.61
# ------------------------------
# State (0,3):
#   Action up: -1.06
#   Action down: -1.00
#   Action left: -1.42
#   Action right: -1.11
# ------------------------------
# State (0,4):
#   Action up: -0.84
#   Action down: -0.91
#   Action left: -0.84
#   Action right: -0.86
# ------------------------------
# State (1,0):
#   Action up: -2.42
#   Action down: -2.18
#   Action left: -2.29
#   Action right: -1.26
# ------------------------------
# State (1,1):
#   Action up: -2.00
#   Action down: -1.62
#   Action left: -1.96
#   Action right: 0.44
# ------------------------------
# State (1,2):
#   Action up: -1.37
#   Action down: 2.51
#   Action left: -1.37
#   Action right: -1.12
# ------------------------------
# State (1,3):
#   Action up: -0.91
#   Action down: 0.98
#   Action left: -0.73
#   Action right: -0.72
# ------------------------------
# State (1,4):
#   Action up: -0.59
#   Action down: -0.44
#   Action left: -0.68
#   Action right: -0.58
# ------------------------------
# State (2,0):
#   Action up: -1.69
#   Action down: -1.58
#   Action left: -1.56
#   Action right: -1.32
# ------------------------------
# State (2,1):
#   Action up: -1.18
#   Action down: -1.10
#   Action left: -1.36
#   Action right: 0.81
# ------------------------------
# State (2,2):
#   Action up: -0.96
#   Action down: -0.20
#   Action left: -0.77
#   Action right: 4.35
# ------------------------------
# State (2,3):
#   Action up: -0.52
#   Action down: 6.13
#   Action left: -0.45
#   Action right: -0.16
# ------------------------------
# State (2,4):
#   Action up: -0.30
#   Action down: 2.43
#   Action left: -0.20
#   Action right: -0.20
# ------------------------------
# State (3,0):
#   Action up: -1.22
#   Action down: -1.10
#   Action left: -1.12
#   Action right: -1.11
# ------------------------------
# State (3,1):
#   Action up: -0.76
#   Action down: -0.69
#   Action left: -0.93
#   Action right: -0.37
# ------------------------------
# State (3,2):
#   Action up: -0.42
#   Action down: -0.13
#   Action left: -0.43
#   Action right: 4.38
# ------------------------------
# State (3,3):
#   Action up: 0.27
#   Action down: 7.99
#   Action left: 0.78
#   Action right: 1.07
# ------------------------------
# State (3,4):
#   Action up: -0.10
#   Action down: 7.71
#   Action left: -0.13
#   Action right: 0.12
# ------------------------------
# State (4,0):
#   Action up: -0.72
#   Action down: -0.68
#   Action left: -0.65
#   Action right: -0.59
# ------------------------------
# State (4,1):
#   Action up: -0.53
#   Action down: -0.49
#   Action left: -0.42
#   Action right: 1.06
# ------------------------------
# State (4,2):
#   Action up: -0.28
#   Action down: 0.06
#   Action left: -0.21
#   Action right: 5.53
# ------------------------------
# State (4,3):
#   Action up: 1.76
#   Action down: 3.52
#   Action left: 0.90
#   Action right: 10.00
# ------------------------------
# State (4,4):
#   Action up: 0.00
#   Action down: 0.00
#   Action left: 0.00
#   Action right: 0.00
# ------------------------------
